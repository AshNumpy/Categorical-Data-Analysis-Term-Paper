# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../Datasets/Ders Sonu Anketi.csv')
df.head()
# Out:
#                  Zaman damgası Cinsiyetiniz   Bölümünüz  \
# 0  2023/05/06 1:18:08 ÖS GMT+3        Erkek    Aktüerya
# 1  2023/05/06 2:27:28 ÖS GMT+3        Erkek    Aktüerya
# 2  2023/05/06 9:07:31 ÖS GMT+3        Erkek  İstatistik
# 3  2023/05/08 2:45:58 ÖS GMT+3        Erkek  İstatistik
# 4  2023/05/08 3:19:14 ÖS GMT+3        Erkek  İstatistik
#
#    [Kız/Erkek arkadaşımın  sosyal medya kullanımı onun hakkındaki fikirlerimi etkiler.]  \
# 0                                                  4
# 1                        1 (Kesinlikle Katılmıyorum)
# 2                                                  4
# 3                         5 (Kesinlikle Katılıyorum)
# 4                         5 (Kesinlikle Katılıyorum)
#
#    [Kız/Erkek arkadaşım telefonumu istediği gibi kurcalayabilir.]  \
# 0                         5 (Kesinlikle Katılıyorum)
# 1                        1 (Kesinlikle Katılmıyorum)
# 2                                                  2
# 3                         5 (Kesinlikle Katılıyorum)
# 4                                                  3
#
#    [İlk buluşmada hesap ortak olarak ödenmeli.]  \
# 0                   1 (Kesinlikle Katılmıyorum)
# 1                    5 (Kesinlikle Katılıyorum)
# 2                                             4
# 3                   1 (Kesinlikle Katılmıyorum)
# 4                    5 (Kesinlikle Katılıyorum)
#
#    [Kız/Erkek arkadaşım ben olmadan gece eğlenmeye çıkabilir.]  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                        1 (Kesinlikle Katılmıyorum)
# 4                         5 (Kesinlikle Katılıyorum)
#
#    [Kız/Erkek arkadaşım giyimime karışabilir.]  \
# 0                                            4
# 1                  1 (Kesinlikle Katılmıyorum)
# 2                                            3
# 3                   5 (Kesinlikle Katılıyorum)
# 4                  1 (Kesinlikle Katılmıyorum)
#
#    [Kız/Erkek arkadaşımın karşı cinsten yakın arkadaşı olabilir.]  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                        1 (Kesinlikle Katılmıyorum)
# 4                         5 (Kesinlikle Katılıyorum)
#
#    [Kız/Erkek arkadaşımın önceki ilişkileri benim için önemsizdir.]  \
# 0                                                  3
# 1                         5 (Kesinlikle Katılıyorum)
# 2                                                  4
# 3                                                  3
# 4                         5 (Kesinlikle Katılıyorum)
#
#   Kız/Erkek arkadaşı seçiminde hangi faktör sizin için en önemlisidir?  \
# 0  Kişinin fiziksel özellikleri (boy, kilo, saç r...
# 1           Kişinin karakteri ve kişilik özellikleri
# 2           Kişinin karakteri ve kişilik özellikleri
# 3           Kişinin karakteri ve kişilik özellikleri
# 4           Kişinin karakteri ve kişilik özellikleri
#
#   Kız/Erkek arkadaşı seçiminde hangi özellikleri önemsiyorsunuz?  \
# 0                Benzer ilgi alanlarına sahip olması
# 1                            Mizah duygusunun olması
# 2                                  Yalan söylememesi
# 3                Benzer ilgi alanlarına sahip olması
# 4                                 Empati yapabilmesi
#
#   Kız/Erkek ilişkilerinde başarının anahtarı sizce nedir?  \
# 0                        Karşılıklı sevgi ve anlayış
# 1                        Karşılıklı sevgi ve anlayış
# 2                                İletişim becerileri
# 3                                İletişim becerileri
# 4                        Karşılıklı sevgi ve anlayış
#
#    Kaç tane romantik ilişkiniz oldu.  En uzun ilişkiniz ne kadar sürdü? (ay)  \
# 0                                  3                                      16
# 1                                  2                                      60
# 2                                  4                                       6
# 3                                  1                                      15
# 4                                  0                                       0
#
#    Kız / Erkek arkadaşınızla bir ayda yaklaşık kaç gün görüşüyorsunuz?
# 0                                                 20
# 1                                                 20
# 2                                                 20
# 3                                                  9
# 4                                                  0

# %%
# write columns to text file
with open('../Datasets/questions.txt', 'w') as f:
    for col in df.columns:
        f.write(col + '\n')
    f.close()

# %%
df.columns
# Out:
# Index(['Zaman damgası', 'Cinsiyetiniz', 'Bölümünüz',
#        ' [Kız/Erkek arkadaşımın  sosyal medya kullanımı onun hakkındaki fikirlerimi etkiler.]',
#        ' [Kız/Erkek arkadaşım telefonumu istediği gibi kurcalayabilir.]',
#        ' [İlk buluşmada hesap ortak olarak ödenmeli.]',
#        ' [Kız/Erkek arkadaşım ben olmadan gece eğlenmeye çıkabilir.]',
#        ' [Kız/Erkek arkadaşım giyimime karışabilir.]',
#        ' [Kız/Erkek arkadaşımın karşı cinsten yakın arkadaşı olabilir.]',
#        ' [Kız/Erkek arkadaşımın önceki ilişkileri benim için önemsizdir.]',
#        'Kız/Erkek arkadaşı seçiminde hangi faktör sizin için en önemlisidir?',
#        'Kız/Erkek arkadaşı seçiminde hangi özellikleri önemsiyorsunuz?',
#        'Kız/Erkek ilişkilerinde başarının anahtarı sizce nedir?',
#        'Kaç tane romantik ilişkiniz oldu.',
#        'En uzun ilişkiniz ne kadar sürdü? (ay)',
#        'Kız / Erkek arkadaşınızla bir ayda yaklaşık kaç gün görüşüyorsunuz?'],
#       dtype='object')

# %%
df.columns = ['DateTime', 'Sex', 'Department', 
            'likert_1', 'likert_2', 'likert_3', 'likert_4', 'likert_5', 'likert_6', 'likert_7',
            'soru8', 'soru9', 'soru10', 'soru11', 'soru12', 'soru13']
df.head(3)
# Out:
#                       DateTime    Sex  Department  \
# 0  2023/05/06 1:18:08 ÖS GMT+3  Erkek    Aktüerya
# 1  2023/05/06 2:27:28 ÖS GMT+3  Erkek    Aktüerya
# 2  2023/05/06 9:07:31 ÖS GMT+3  Erkek  İstatistik
#
#                       likert_1                     likert_2  \
# 0                            4   5 (Kesinlikle Katılıyorum)
# 1  1 (Kesinlikle Katılmıyorum)  1 (Kesinlikle Katılmıyorum)
# 2                            4                            2
#
#                       likert_3 likert_4                     likert_5 likert_6  \
# 0  1 (Kesinlikle Katılmıyorum)        4                            4        3
# 1   5 (Kesinlikle Katılıyorum)        4  1 (Kesinlikle Katılmıyorum)        3
# 2                            4        4                            3        3
#
#                      likert_7  \
# 0                           3
# 1  5 (Kesinlikle Katılıyorum)
# 2                           4
#
#                                                soru8  \
# 0  Kişinin fiziksel özellikleri (boy, kilo, saç r...
# 1           Kişinin karakteri ve kişilik özellikleri
# 2           Kişinin karakteri ve kişilik özellikleri
#
#                                  soru9                       soru10  soru11  \
# 0  Benzer ilgi alanlarına sahip olması  Karşılıklı sevgi ve anlayış       3
# 1              Mizah duygusunun olması  Karşılıklı sevgi ve anlayış       2
# 2                    Yalan söylememesi          İletişim becerileri       4
#
#    soru12  soru13
# 0      16      20
# 1      60      20
# 2       6      20

# %%
import re

# Regex ile tarih kısmını ayıklama
pattern = r'(\d{4}/\d{2}/\d{2})'

df['Date'] = df['DateTime'].str.extract(pattern)

df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')
df.head(3)
# Out:
#                       DateTime    Sex  Department  \
# 0  2023/05/06 1:18:08 ÖS GMT+3  Erkek    Aktüerya
# 1  2023/05/06 2:27:28 ÖS GMT+3  Erkek    Aktüerya
# 2  2023/05/06 9:07:31 ÖS GMT+3  Erkek  İstatistik
#
#                       likert_1                     likert_2  \
# 0                            4   5 (Kesinlikle Katılıyorum)
# 1  1 (Kesinlikle Katılmıyorum)  1 (Kesinlikle Katılmıyorum)
# 2                            4                            2
#
#                       likert_3 likert_4                     likert_5 likert_6  \
# 0  1 (Kesinlikle Katılmıyorum)        4                            4        3
# 1   5 (Kesinlikle Katılıyorum)        4  1 (Kesinlikle Katılmıyorum)        3
# 2                            4        4                            3        3
#
#                      likert_7  \
# 0                           3
# 1  5 (Kesinlikle Katılıyorum)
# 2                           4
#
#                                                soru8  \
# 0  Kişinin fiziksel özellikleri (boy, kilo, saç r...
# 1           Kişinin karakteri ve kişilik özellikleri
# 2           Kişinin karakteri ve kişilik özellikleri
#
#                                  soru9                       soru10  soru11  \
# 0  Benzer ilgi alanlarına sahip olması  Karşılıklı sevgi ve anlayış       3
# 1              Mizah duygusunun olması  Karşılıklı sevgi ve anlayış       2
# 2                    Yalan söylememesi          İletişim becerileri       4
#
#    soru12  soru13       Date
# 0      16      20 2023-05-06
# 1      60      20 2023-05-06
# 2       6      20 2023-05-06

# %%
df.iloc[0,4]
# Out:
# '5 (Kesinlikle Katılıyorum)'

# %%
for i in range(1, 8):
    df.loc[df[f'likert_{i}'] == '5 (Kesinlikle Katılıyorum)', f'likert_{i}'] = 5
    df.loc[df[f'likert_{i}'] == '1 (Kesinlikle Katılmıyorum)', f'likert_{i}'] = 1

df.head(3)
# Out:
#                       DateTime    Sex  Department likert_1 likert_2 likert_3  \
# 0  2023/05/06 1:18:08 ÖS GMT+3  Erkek    Aktüerya        4        5        1
# 1  2023/05/06 2:27:28 ÖS GMT+3  Erkek    Aktüerya        1        1        5
# 2  2023/05/06 9:07:31 ÖS GMT+3  Erkek  İstatistik        4        2        4
#
#   likert_4 likert_5 likert_6 likert_7  \
# 0        4        4        3        3
# 1        4        1        3        5
# 2        4        3        3        4
#
#                                                soru8  \
# 0  Kişinin fiziksel özellikleri (boy, kilo, saç r...
# 1           Kişinin karakteri ve kişilik özellikleri
# 2           Kişinin karakteri ve kişilik özellikleri
#
#                                  soru9                       soru10  soru11  \
# 0  Benzer ilgi alanlarına sahip olması  Karşılıklı sevgi ve anlayış       3
# 1              Mizah duygusunun olması  Karşılıklı sevgi ve anlayış       2
# 2                    Yalan söylememesi          İletişim becerileri       4
#
#    soru12  soru13       Date
# 0      16      20 2023-05-06
# 1      60      20 2023-05-06
# 2       6      20 2023-05-06

# %%
df.drop(['DateTime'], axis=1, inplace=True)
df.head(3)
# Out:
#      Sex  Department likert_1 likert_2 likert_3 likert_4 likert_5 likert_6  \
# 0  Erkek    Aktüerya        4        5        1        4        4        3
# 1  Erkek    Aktüerya        1        1        5        4        1        3
# 2  Erkek  İstatistik        4        2        4        4        3        3
#
#   likert_7                                              soru8  \
# 0        3  Kişinin fiziksel özellikleri (boy, kilo, saç r...
# 1        5           Kişinin karakteri ve kişilik özellikleri
# 2        4           Kişinin karakteri ve kişilik özellikleri
#
#                                  soru9                       soru10  soru11  \
# 0  Benzer ilgi alanlarına sahip olması  Karşılıklı sevgi ve anlayış       3
# 1              Mizah duygusunun olması  Karşılıklı sevgi ve anlayış       2
# 2                    Yalan söylememesi          İletişim becerileri       4
#
#    soru12  soru13       Date
# 0      16      20 2023-05-06
# 1      60      20 2023-05-06
# 2       6      20 2023-05-06

# %%
df['soru8'].value_counts()
# Out:
# Kişinin karakteri ve kişilik özellikleri                   78
# Kişinin fiziksel özellikleri (boy, kilo, saç rengi vb.)    11
# Kişinin maddi ve ekonomik durumu                            5
# Name: soru8, dtype: int64

# %%
df['soru9'].value_counts()
# Out:
# Benzer ilgi alanlarına sahip olması    33
# Yalan söylememesi                      21
# Mizah duygusunun olması                19
# Empati yapabilmesi                     17
# İyi bir dinleyici olması                4
# Name: soru9, dtype: int64

# %%
df['soru10'].value_counts()
# Out:
# Karşılıklı sevgi ve anlayış    60
# İletişim becerileri            29
# Ortak ilgi ve hobiler           5
# Name: soru10, dtype: int64

# %%
df = df[['Date', 'Sex', 'Department', 'likert_1', 'likert_2', 'likert_3', 'likert_4',
       'likert_5', 'likert_6', 'likert_7', 'soru8', 'soru9', 'soru10',
       'soru11', 'soru12', 'soru13']]
df.head(3)
# Out:
#         Date    Sex  Department likert_1 likert_2 likert_3 likert_4 likert_5  \
# 0 2023-05-06  Erkek    Aktüerya        4        5        1        4        4
# 1 2023-05-06  Erkek    Aktüerya        1        1        5        4        1
# 2 2023-05-06  Erkek  İstatistik        4        2        4        4        3
#
#   likert_6 likert_7                                              soru8  \
# 0        3        3  Kişinin fiziksel özellikleri (boy, kilo, saç r...
# 1        3        5           Kişinin karakteri ve kişilik özellikleri
# 2        3        4           Kişinin karakteri ve kişilik özellikleri
#
#                                  soru9                       soru10  soru11  \
# 0  Benzer ilgi alanlarına sahip olması  Karşılıklı sevgi ve anlayış       3
# 1              Mizah duygusunun olması  Karşılıklı sevgi ve anlayış       2
# 2                    Yalan söylememesi          İletişim becerileri       4
#
#    soru12  soru13
# 0      16      20
# 1      60      20
# 2       6      20

# %%
df.to_csv('../Datasets/processed.csv', index=False)
